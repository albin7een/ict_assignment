# %% [markdown]
# <a href="https://colab.research.google.com/github/albin7een/ict_assignment/blob/main/assigment3_albin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1 question

# %%
max(12,29,23)
# Out:
# 29

# %% [markdown]
# 2 question

# %%
list1=[18,12,30,10,7]
sum=0
for i in list1:
  sum=sum+i
print(sum)
# Out:
# 77

# %% [markdown]
# 3 question

# %%
number=[32,34,45,12,23]

# %%
number.insert(3,77)

# %%
number
# Out:
# [32, 34, 45, 77, 12, 23]

# %% [markdown]
# 4 question

# %%
sample_dict = { "name": "Kelly", "age":25, "salary": 8000, "city": "New york"}

# %%
sample_dict
# Out:
# {'name': 'Kelly', 'age': 25, 'salary': 8000, 'city': 'New york'}

# %%
sample_dict = { "name": "Kelly", "age":25, "salary": 8000, "city": "New york"}
sample_dict.pop("city")
sample_dict.update({"location":"new york"})

# %%
sample_dict
# Out:
# {'name': 'Kelly', 'age': 25, 'salary': 8000, 'location': 'new york'}

# %% [markdown]
# 5 question

# %%
sample_dict = {
 'emp1': {'name': 'Jhon', 'salary': 7500},
 'emp2': {'name': 'Emma', 'salary': 8000},
 'emp3': {'name': 'Brad', 'salary':500}
}
sample_dict["emp3"]["salary"]=8500

# %%
sample_dict
# Out:
# {'emp1': {'name': 'Jhon', 'salary': 7500},
#  'emp2': {'name': 'Emma', 'salary': 8000},
#  'emp3': {'name': 'Brad', 'salary': 8500}}

# %% [markdown]
# 6 question

# %%
tuple1=(11,22,33,44,55,66)
new_tuple=(tuple1[3],tuple1[4])
print(new_tuple)
# Out:
# (44, 55)

# %% [markdown]
#  7 question

# %%
tuple3=(50,10,60,70,83,567,50,81)
tuple3.count(50)
# Out:
# 2
